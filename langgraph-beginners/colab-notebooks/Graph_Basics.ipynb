# %%
# !pip install langgraph
# Out:
# Requirement already satisfied: langgraph in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (1.0.5)
# Requirement already satisfied: langchain-core>=0.1 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph) (1.2.5)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph) (0.3.0)
# Requirement already satisfied: pydantic>=2.7.4 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph) (2.11.10)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.5)
# Requirement already satisfied: anyio in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.10.0)
# Requirement already satisfied: certifi in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langchain-core>=0.1->langgraph) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/madhusudhananjeyaram/miniconda3/envs/myenv/lib/python3.12/site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.0)

# %%
import os
from dotenv import load_dotenv
from langgraph.graph import START, END, StateGraph
from typing import TypedDict, Literal
import random

# Load environment variables from .env file
load_dotenv()

# Get API keys if needed
openai_key = os.getenv("OPENAI_API_KEY")
groq_key = os.getenv("GROQ_API_KEY")

# %%
class JourneyState(TypedDict):
    current_location: str

# %%
def coimbatore(state: JourneyState) -> JourneyState:
  print("📍 Starting journey from Coimbatore")
  return {"current_location": "Departed from Coimbatore"}

# %%
def trichy(state: JourneyState) -> JourneyState:
    print("🚗 Arrived at Trichy")
    return {"current_location": "Visited Trichy"}

def salem(state: JourneyState) -> JourneyState:
    print("🚗 Arrived at Salem")
    return {"current_location": "Visited Salem"}

# %%
def decide_intermediate_city(state: JourneyState) -> Literal["trichy", "salem"]:
    print(f"🗺️  Deciding route... Last update: {state['current_location']}")
    if random.random() < 0.5:
        print("--> Route selected: Trichy")
        return "trichy"
    else:
        print("--> Route selected: Salem")
        return "salem"

# %%
builder = StateGraph(JourneyState)

# %%
builder.add_node("coimbatore", coimbatore)
builder.add_node("trichy", trichy)
builder.add_node("salem", salem)

# %%
builder.add_edge(START, "coimbatore")

# %%
builder.add_conditional_edges("coimbatore", decide_intermediate_city)

# %%
builder.add_edge("trichy", END)
builder.add_edge("salem", END)

# %%
graph = builder.compile()

# %%
from IPython.display import Image, display

# %%
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
graph.invoke({"current_location" : "Coimbatore"})
# Out:
# 📍 Starting journey from Coimbatore
# 🗺️  Deciding route... Last update: Departed from Coimbatore
# --> Route selected: Salem
# 🚗 Arrived at Salem
# {'current_location': 'Visited Salem'}
